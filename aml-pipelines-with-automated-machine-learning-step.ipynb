# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.18.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-128181
# aml-quickstarts-128181
# southcentralus
# 422c78cb-7b9f-41e7-a94c-e144f7afde5e

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'ml-experiment-1'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: ml-experiment-1,
# Workspace: quick-starts-ws-128181)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "auto-ml"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Creating
# Succeeded........................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [bca26b2c][2820336a-d488-40f1-98e1-ce199fa9d7b7], (This step will run and generate new outputs)
# Submitted PipelineRun 3220a35b-db7b-420c-8f46-c0f87a5e62ed
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/3220a35b-db7b-420c-8f46-c0f87a5e62ed?wsid=/subscriptions/422c78cb-7b9f-41e7-a94c-e144f7afde5e/resourcegroups/aml-quickstarts-128181/workspaces/quick-starts-ws-128181

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 3220a35b-db7b-420c-8f46-c0f87a5e62ed
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/3220a35b-db7b-420c-8f46-c0f87a5e62ed?wsid=/subscriptions/422c78cb-7b9f-41e7-a94c-e144f7afde5e/resourcegroups/aml-quickstarts-128181/workspaces/quick-starts-ws-128181
# PipelineRun Status: Running
#
#
# StepRunId: 6375497e-6545-4057-b06a-e71c25f86f31
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/6375497e-6545-4057-b06a-e71c25f86f31?wsid=/subscriptions/422c78cb-7b9f-41e7-a94c-e144f7afde5e/resourcegroups/aml-quickstarts-128181/workspaces/quick-starts-ws-128181
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '6375497e-6545-4057-b06a-e71c25f86f31', 'target': 'auto-ml', 'status': 'Completed', 'startTimeUtc': '2020-11-28T09:13:11.416957Z', 'endTimeUtc': '2020-11-28T09:54:17.393622Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '22d50526-828a-436c-963c-90c603ee70e4', 'StepType': 'AutoMLStep', 'azureml.moduleid': '2820336a-d488-40f1-98e1-ce199fa9d7b7', 'azureml.nodeid': 'bca26b2c', 'azureml.pipelinerunid': '3220a35b-db7b-420c-8f46-c0f87a5e62ed', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'auto-ml', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "422c78cb-7b9f-41e7-a94c-e144f7afde5e", "resource_group": "aml-quickstarts-128181", "workspace_name": "quick-starts-ws-128181", "region": "southcentralus", "compute_target": "auto-ml", "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["TensorFlowDNN", "LogisticRegression", "LinearSVM", "SGD", "MultinomialNaiveBayes", "RandomForest", "DecisionTree", "SVM", "LightGBM", "XGBoostClassifier", "TensorFlowLinearClassifier", "BernoulliNaiveBayes", "KNN", "GradientBoosting", "ExtremeRandomTrees", "AveragedPerceptronClassifier"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_D2_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"b2364e0e-9622-4efc-9530-190e5c8e0a7e\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '22d50526-828a-436c-963c-90c603ee70e4', 'SetupRunId': '6375497e-6545-4057-b06a-e71c25f86f31_setup', 'SetupRunContainerId': 'dcid.6375497e-6545-4057-b06a-e71c25f86f31_setup', 'ClientSdkVersion': '1.18.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': '6375497e-6545-4057-b06a-e71c25f86f31_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_classes ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '3220a35b-db7b-420c-8f46-c0f87a5e62ed', 'status': 'Completed', 'startTimeUtc': '2020-11-28T09:12:36.179069Z', 'endTimeUtc': '2020-11-28T09:55:58.761699Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg128181.blob.core.windows.net/azureml/ExperimentRun/dcid.3220a35b-db7b-420c-8f46-c0f87a5e62ed/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=6p76URh83tbzYxD97w%2BTKb0gfAgz0psksddGF1dM7Uw%3D&st=2020-11-28T09%3A02%3A45Z&se=2020-11-28T17%3A12%3A45Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg128181.blob.core.windows.net/azureml/ExperimentRun/dcid.3220a35b-db7b-420c-8f46-c0f87a5e62ed/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=WujAXY6E%2BNnft9h5DDbEuejW8rKvFCWU3%2B2lGOG5XMQ%3D&st=2020-11-28T09%3A02%3A45Z&se=2020-11-28T17%3A12%3A45Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg128181.blob.core.windows.net/azureml/ExperimentRun/dcid.3220a35b-db7b-420c-8f46-c0f87a5e62ed/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=SveV60QWZLPs%2BneafRRCwnFXSEHLDppZgEvrJzdylL4%3D&st=2020-11-28T09%3A02%3A45Z&se=2020-11-28T17%3A12%3A45Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/6375497e-6545-4057-b06a-e71c25f86f31/metrics_data
# Downloaded azureml/6375497e-6545-4057-b06a-e71c25f86f31/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  6375497e-6545-4057-b06a-e71c25f86f31_6  \
# accuracy                                           [0.8977238239757208]
# precision_score_macro                               [0.771526544069397]
# norm_macro_recall                                 [0.18855620203502088]
# weighted_accuracy                                  [0.9730611889183236]
# AUC_micro                                          [0.9677808607790809]
# average_precision_score_micro                      [0.9682183253674135]
# log_loss                                           [0.2432779762995486]
# precision_score_weighted                            [0.877014103638037]
# balanced_accuracy                                  [0.5942781010175104]
# AUC_macro                                          [0.8993080446867353]
# average_precision_score_weighted                   [0.9284453110289542]
# recall_score_micro                                 [0.8977238239757208]
# f1_score_macro                                     [0.6263947343363969]
# recall_score_macro                                 [0.5942781010175104]
# average_precision_score_macro                      [0.7296965673408553]
# precision_score_micro                              [0.8977238239757208]
# matthews_correlation                              [0.31999379338174755]
# f1_score_weighted                                  [0.8734704046383025]
# AUC_weighted                                       [0.8993080446867354]
# f1_score_micro                                     [0.8977238239757208]
# recall_score_weighted                              [0.8977238239757208]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_7  \
# accuracy                                           [0.9013657056145675]
# precision_score_macro                              [0.7809496818076418]
# norm_macro_recall                                 [0.24239089964378802]
# weighted_accuracy                                  [0.9709244016507014]
# AUC_micro                                          [0.9707084583483966]
# average_precision_score_micro                      [0.9698260481749431]
# log_loss                                          [0.23963883417392468]
# precision_score_weighted                           [0.8836184957037101]
# balanced_accuracy                                   [0.621195449821894]
# AUC_macro                                          [0.9206404777649964]
# average_precision_score_weighted                   [0.9373731444911663]
# recall_score_micro                                 [0.9013657056145675]
# f1_score_macro                                     [0.6589288734325538]
# recall_score_macro                                  [0.621195449821894]
# average_precision_score_macro                      [0.7567343759080069]
# precision_score_micro                              [0.9013657056145675]
# matthews_correlation                               [0.3690518828782486]
# f1_score_weighted                                  [0.8820789741846808]
# AUC_weighted                                       [0.9206404777649965]
# f1_score_micro                                     [0.9013657056145675]
# recall_score_weighted                              [0.9013657056145675]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_24  \
# accuracy                                            [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# norm_macro_recall                                                  [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9671455117769371]
# average_precision_score_micro                       [0.9672159319124674]
# log_loss                                            [0.2323181707802995]
# precision_score_weighted                             [0.788565560086672]
# balanced_accuracy                                                  [0.5]
# AUC_macro                                           [0.8978687479971177]
# average_precision_score_weighted                    [0.9212396768818438]
# recall_score_micro                                  [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_macro                                                 [0.5]
# average_precision_score_macro                       [0.6981086223963937]
# precision_score_micro                               [0.8880121396054628]
# matthews_correlation                                               [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# AUC_weighted                                        [0.8978687479971177]
# f1_score_micro                                      [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_17  \
# accuracy                                            [0.8986342943854325]
# precision_score_macro                               [0.7590688139558655]
# norm_macro_recall                                  [0.25352460975054036]
# weighted_accuracy                                   [0.9661327553679234]
# AUC_micro                                            [0.969123033243453]
# average_precision_score_micro                       [0.9701985744586034]
# log_loss                                           [0.23312811330730418]
# precision_score_weighted                             [0.879754959866722]
# balanced_accuracy                                   [0.6267623048752702]
# AUC_macro                                           [0.9060289304191743]
# average_precision_score_weighted                    [0.9339158146952048]
# recall_score_micro                                  [0.8986342943854325]
# f1_score_macro                                      [0.6619968943260024]
# recall_score_macro                                  [0.6267623048752702]
# average_precision_score_macro                        [0.749280145371371]
# precision_score_micro                               [0.8986342943854325]
# matthews_correlation                               [0.36243708407583286]
# f1_score_weighted                                   [0.8814679976818104]
# AUC_weighted                                        [0.9060289304191743]
# f1_score_micro                                      [0.8986342943854325]
# recall_score_weighted                               [0.8986342943854325]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_10  \
# accuracy                                            [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# norm_macro_recall                                                  [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9671568408472855]
# average_precision_score_micro                        [0.968128338345806]
# log_loss                                            [0.2580285907335299]
# precision_score_weighted                             [0.788565560086672]
# balanced_accuracy                                                  [0.5]
# AUC_macro                                            [0.897925708580394]
# average_precision_score_weighted                    [0.9272529332814596]
# recall_score_micro                                  [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_macro                                                 [0.5]
# average_precision_score_macro                       [0.7249488820814525]
# precision_score_micro                               [0.8880121396054628]
# matthews_correlation                                               [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# AUC_weighted                                        [0.8979257085803941]
# f1_score_micro                                      [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_5  \
# accuracy                                           [0.8995447647951441]
# precision_score_macro                              [0.8079736522794245]
# norm_macro_recall                                 [0.16455588342622995]
# weighted_accuracy                                  [0.9783135350440586]
# AUC_micro                                          [0.9633971552980674]
# average_precision_score_micro                      [0.9642059190568857]
# log_loss                                           [0.2558378018018011]
# precision_score_weighted                           [0.8831413359721035]
# balanced_accuracy                                   [0.582277941713115]
# AUC_macro                                          [0.8769711603472836]
# average_precision_score_weighted                   [0.9244560261046363]
# recall_score_micro                                 [0.8995447647951441]
# f1_score_macro                                     [0.6124395861028403]
# recall_score_macro                                  [0.582277941713115]
# average_precision_score_macro                      [0.7244975863199279]
# precision_score_micro                              [0.8995447647951441]
# matthews_correlation                               [0.3183673237719075]
# f1_score_weighted                                  [0.8712999323356404]
# AUC_weighted                                       [0.8769711603472836]
# f1_score_micro                                     [0.8995447647951441]
# recall_score_weighted                              [0.8995447647951441]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_1  \
# accuracy                                           [0.9071320182094081]
# precision_score_macro                              [0.7723958081530135]
# norm_macro_recall                                 [0.43834549418631563]
# weighted_accuracy                                  [0.9537972210153172]
# AUC_micro                                          [0.9781770788959222]
# average_precision_score_micro                      [0.9791945367231853]
# log_loss                                           [0.1874363495858499]
# precision_score_weighted                           [0.8991976076061607]
# balanced_accuracy                                  [0.7191727470931578]
# AUC_macro                                          [0.9392346349984347]
# average_precision_score_weighted                   [0.9505970434373063]
# recall_score_micro                                 [0.9071320182094081]
# f1_score_macro                                     [0.7416848907681176]
# recall_score_macro                                 [0.7191727470931578]
# average_precision_score_macro                      [0.8065229883244922]
# precision_score_micro                              [0.9071320182094081]
# matthews_correlation                                [0.488678780261868]
# f1_score_weighted                                  [0.9021127651963996]
# AUC_weighted                                       [0.9392346349984347]
# f1_score_micro                                     [0.9071320182094081]
# recall_score_weighted                              [0.9071320182094081]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_13  \
# accuracy                                            [0.7693474962063733]
# precision_score_macro                               [0.6253214606738522]
# norm_macro_recall                                   [0.5129064346009149]
# weighted_accuracy                                   [0.7725487968743695]
# AUC_micro                                           [0.8420039559639957]
# average_precision_score_micro                       [0.8220243467340418]
# log_loss                                            [0.5793112851798615]
# precision_score_weighted                            [0.8844872403055598]
# balanced_accuracy                                   [0.7564532173004574]
# AUC_macro                                           [0.8583936745040724]
# average_precision_score_weighted                    [0.9205249638796521]
# recall_score_micro                                  [0.7693474962063733]
# f1_score_macro                                      [0.6371200063064202]
# recall_score_macro                                  [0.7564532173004574]
# average_precision_score_macro                       [0.7169869401497935]
# precision_score_micro                               [0.7693474962063733]
# matthews_correlation                               [0.35854758003144926]
# f1_score_weighted                                   [0.8071077849259176]
# AUC_weighted                                        [0.8583936745040723]
# f1_score_micro                                      [0.7693474962063733]
# recall_score_weighted                               [0.7693474962063733]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_26  \
# accuracy                                            [0.8992412746585736]
# precision_score_macro                               [0.7728697364589063]
# norm_macro_recall                                  [0.21868418274066537]
# weighted_accuracy                                   [0.9712154002288209]
# AUC_micro                                           [0.9731014711672858]
# average_precision_score_micro                       [0.9739286041202228]
# log_loss                                            [0.2334302011411114]
# precision_score_weighted                            [0.8798316772654436]
# balanced_accuracy                                   [0.6093420913703327]
# AUC_macro                                           [0.9231587838776543]
# average_precision_score_weighted                    [0.9411384532313263]
# recall_score_micro                                  [0.8992412746585736]
# f1_score_macro                                      [0.6446520777624456]
# recall_score_macro                                  [0.6093420913703327]
# average_precision_score_macro                       [0.7718553931451823]
# precision_score_micro                               [0.8992412746585736]
# matthews_correlation                               [0.34546286432025275]
# f1_score_weighted                                   [0.8780635429698314]
# AUC_weighted                                        [0.9231587838776544]
# f1_score_micro                                      [0.8992412746585736]
# recall_score_weighted                               [0.8992412746585736]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_2  ...  \
# accuracy                                           [0.8968133535660091]  ...
# precision_score_macro                              [0.8414478615120524]  ...
# norm_macro_recall                                 [0.10464168551459951]  ...
# weighted_accuracy                                  [0.9823415256350664]  ...
# AUC_micro                                          [0.9692577847062155]  ...
# average_precision_score_micro                      [0.9705995893825115]  ...
# log_loss                                           [0.2354048941297406]  ...
# precision_score_weighted                           [0.8857853382367525]  ...
# balanced_accuracy                                  [0.5523208427572998]  ...
# AUC_macro                                          [0.9074510926243917]  ...
# average_precision_score_weighted                    [0.936352609363634]  ...
# recall_score_micro                                 [0.8968133535660091]  ...
# f1_score_macro                                     [0.5676854210079494]  ...
# recall_score_macro                                 [0.5523208427572998]  ...
# average_precision_score_macro                      [0.7590521541980849]  ...
# precision_score_micro                              [0.8968133535660091]  ...
# matthews_correlation                               [0.2673188348918823]  ...
# f1_score_weighted                                  [0.8604089422430654]  ...
# AUC_weighted                                       [0.9074510926243917]  ...
# f1_score_micro                                     [0.8968133535660091]  ...
# recall_score_weighted                              [0.8968133535660091]  ...
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_19  \
# accuracy                                            [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# norm_macro_recall                                                  [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9653214393445719]
# average_precision_score_micro                       [0.9661740362041048]
# log_loss                                           [0.28410056452605154]
# precision_score_weighted                             [0.788565560086672]
# balanced_accuracy                                                  [0.5]
# AUC_macro                                           [0.8886976309954487]
# average_precision_score_weighted                    [0.9272178727279098]
# recall_score_micro                                  [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_macro                                                 [0.5]
# average_precision_score_macro                       [0.7302778845109504]
# precision_score_micro                               [0.8880121396054628]
# matthews_correlation                                               [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# AUC_weighted                                        [0.8886976309954486]
# f1_score_micro                                      [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_32  \
# accuracy                                            [0.9150227617602428]
# precision_score_macro                               [0.7914628378800695]
# norm_macro_recall                                   [0.5182792531958129]
# weighted_accuracy                                   [0.9537243276535915]
# AUC_micro                                           [0.9794055922317577]
# average_precision_score_micro                       [0.9803672686898925]
# log_loss                                           [0.18027994959633623]
# precision_score_weighted                            [0.9107315148757672]
# balanced_accuracy                                   [0.7591396265979065]
# AUC_macro                                           [0.9444009135921845]
# average_precision_score_weighted                    [0.9521757313222089]
# recall_score_micro                                  [0.9150227617602428]
# f1_score_macro                                      [0.7739510013191502]
# recall_score_macro                                  [0.7591396265979065]
# average_precision_score_macro                       [0.8110321176902837]
# precision_score_micro                               [0.9150227617602428]
# matthews_correlation                                [0.5496528758240327]
# f1_score_weighted                                   [0.9125297533160284]
# AUC_weighted                                        [0.9444009135921847]
# f1_score_micro                                      [0.9150227617602428]
# recall_score_weighted                               [0.9150227617602428]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_35  \
# accuracy                                            [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# norm_macro_recall                                                  [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9599150780255181]
# average_precision_score_micro                        [0.960678487507017]
# log_loss                                           [0.34982940479517965]
# precision_score_weighted                             [0.788565560086672]
# balanced_accuracy                                                  [0.5]
# AUC_macro                                           [0.8615153923241214]
# average_precision_score_weighted                    [0.9177794038604259]
# recall_score_micro                                  [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_macro                                                 [0.5]
# average_precision_score_macro                       [0.7037445002655882]
# precision_score_micro                               [0.8880121396054628]
# matthews_correlation                                               [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# AUC_weighted                                        [0.8615153923241214]
# f1_score_micro                                      [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_21  \
# accuracy                                            [0.7256449165402125]
# precision_score_macro                               [0.6054611422732865]
# norm_macro_recall                                  [0.46842901785135416]
# weighted_accuracy                                   [0.7235173185544534]
# AUC_micro                                           [0.8213702188214543]
# average_precision_score_micro                       [0.7977492884493602]
# log_loss                                            [0.5380494018398184]
# precision_score_weighted                            [0.8786255074293129]
# balanced_accuracy                                   [0.7342145089256771]
# AUC_macro                                           [0.8561879569581752]
# average_precision_score_weighted                    [0.9181228828630759]
# recall_score_micro                                  [0.7256449165402125]
# f1_score_macro                                      [0.6011271945047929]
# recall_score_macro                                  [0.7342145089256771]
# average_precision_score_macro                       [0.7069165875614563]
# precision_score_micro                               [0.7256449165402125]
# matthews_correlation                                [0.3143280429632632]
# f1_score_weighted                                   [0.7740722326604518]
# AUC_weighted                                        [0.8561879569581752]
# f1_score_micro                                      [0.7256449165402123]
# recall_score_weighted                               [0.7256449165402125]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_34  \
# accuracy                                            [0.9186646433990895]
# precision_score_macro                               [0.8075299061149223]
# norm_macro_recall                                   [0.5010660427861968]
# weighted_accuracy                                   [0.9604071772597547]
# AUC_micro                                           [0.9798930185755306]
# average_precision_score_micro                       [0.9808136087836803]
# log_loss                                           [0.18264343321000462]
# precision_score_weighted                            [0.9124289549283647]
# balanced_accuracy                                   [0.7505330213930984]
# AUC_macro                                           [0.9448779005903525]
# average_precision_score_weighted                    [0.9539040173301733]
# recall_score_micro                                  [0.9186646433990895]
# f1_score_macro                                       [0.774978493176935]
# recall_score_macro                                  [0.7505330213930984]
# average_precision_score_macro                       [0.8186538124518388]
# precision_score_micro                               [0.9186646433990895]
# matthews_correlation                                [0.5551446533929958]
# f1_score_weighted                                    [0.914517226985537]
# AUC_weighted                                        [0.9448779005903525]
# f1_score_micro                                      [0.9186646433990896]
# recall_score_weighted                               [0.9186646433990895]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_14  \
# accuracy                                            [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# norm_macro_recall                                                  [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# AUC_micro                                           [0.9600592243271061]
# average_precision_score_micro                       [0.9600870469533391]
# log_loss                                            [0.2652237560932925]
# precision_score_weighted                             [0.788565560086672]
# balanced_accuracy                                                  [0.5]
# AUC_macro                                            [0.862240134704833]
# average_precision_score_weighted                    [0.9133236862250709]
# recall_score_micro                                  [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_macro                                                 [0.5]
# average_precision_score_macro                       [0.6835767988679085]
# precision_score_micro                               [0.8880121396054628]
# matthews_correlation                                               [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# AUC_weighted                                        [0.8622401347048331]
# f1_score_micro                                      [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_9  \
# accuracy                                           [0.8992412746585736]
# precision_score_macro                              [0.7870079564489112]
# norm_macro_recall                                  [0.1878967559326994]
# weighted_accuracy                                   [0.975037242874128]
# AUC_micro                                          [0.9694323260745923]
# average_precision_score_micro                      [0.9701235952401777]
# log_loss                                           [0.2908708728237757]
# precision_score_weighted                           [0.8803957191114906]
# balanced_accuracy                                  [0.5939483779663497]
# AUC_macro                                          [0.9058223904180258]
# average_precision_score_weighted                   [0.9365582165290047]
# recall_score_micro                                 [0.8992412746585736]
# f1_score_macro                                     [0.6269980905619204]
# recall_score_macro                                 [0.5939483779663497]
# average_precision_score_macro                      [0.7629678795837858]
# precision_score_micro                              [0.8992412746585736]
# matthews_correlation                               [0.3284139581187861]
# f1_score_weighted                                  [0.8742896791001592]
# AUC_weighted                                       [0.9058223904180259]
# f1_score_micro                                     [0.8992412746585736]
# recall_score_weighted                              [0.8992412746585736]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_22  \
# accuracy                                            [0.7380880121396055]
# precision_score_macro                               [0.6078012816391265]
# norm_macro_recall                                  [0.46586347613305246]
# weighted_accuracy                                   [0.7393681755170973]
# AUC_micro                                           [0.8271964925935051]
# average_precision_score_micro                       [0.7946469194437353]
# log_loss                                            [0.5656190453463273]
# precision_score_weighted                            [0.8775528362057053]
# balanced_accuracy                                   [0.7329317380665262]
# AUC_macro                                           [0.8253491266970086]
# average_precision_score_weighted                    [0.9092099386389223]
# recall_score_micro                                  [0.7380880121396055]
# f1_score_macro                                      [0.6084407650619805]
# recall_score_macro                                  [0.7329317380665262]
# average_precision_score_macro                        [0.701521849658292]
# precision_score_micro                               [0.7380880121396055]
# matthews_correlation                                [0.3169248484925145]
# f1_score_weighted                                   [0.7832867623074906]
# AUC_weighted                                        [0.8253491266970087]
# f1_score_micro                                      [0.7380880121396055]
# recall_score_weighted                               [0.7380880121396055]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_23  \
# accuracy                                            [0.8995447647951441]
# precision_score_macro                               [0.7998633923384806]
# norm_macro_recall                                  [0.17402893782868123]
# weighted_accuracy                                   [0.9771375834608871]
# AUC_micro                                           [0.9615659906834514]
# average_precision_score_micro                       [0.9617439110194038]
# log_loss                                            [0.2603056433289855]
# precision_score_weighted                            [0.8821109784539012]
# balanced_accuracy                                   [0.5870144689143406]
# AUC_macro                                           [0.8679950059924386]
# average_precision_score_weighted                    [0.9233806728380969]
# recall_score_micro                                  [0.8995447647951441]
# f1_score_macro                                      [0.6185810443369875]
# recall_score_macro                                  [0.5870144689143406]
# average_precision_score_macro                       [0.7279722712530468]
# precision_score_micro                               [0.8995447647951441]
# matthews_correlation                                [0.3230631754390179]
# f1_score_weighted                                   [0.8726207307625555]
# AUC_weighted                                        [0.8679950059924387]
# f1_score_micro                                      [0.8995447647951441]
# recall_score_weighted                               [0.8995447647951441]
#
#                                  6375497e-6545-4057-b06a-e71c25f86f31_28
# accuracy                                            [0.8983308042488619]
# precision_score_macro                               [0.7444537802338271]
# norm_macro_recall                                    [0.416593034693163]
# weighted_accuracy                                   [0.9455111773462148]
# AUC_micro                                           [0.9662694891095858]
# average_precision_score_micro                       [0.9606329585158543]
# log_loss                                           [0.23894163090068116]
# precision_score_weighted                            [0.8913233399226826]
# balanced_accuracy                                   [0.7082965173465815]
# AUC_macro                                           [0.9241090531206064]
# average_precision_score_weighted                    [0.9405365021938871]
# recall_score_micro                                  [0.8983308042488619]
# f1_score_macro                                      [0.7242575193581177]
# recall_score_macro                                  [0.7082965173465815]
# average_precision_score_macro                       [0.7689532236473247]
# precision_score_micro                               [0.8983308042488619]
# matthews_correlation                               [0.45130420372477276]
# f1_score_weighted                                   [0.8942748568163426]
# AUC_weighted                                        [0.9241090531206064]
# f1_score_micro                                      [0.8983308042488619]
# recall_score_weighted                               [0.8983308042488619]
#
# [21 rows x 39 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/6375497e-6545-4057-b06a-e71c25f86f31/model_data
# Downloaded azureml/6375497e-6545-4057-b06a-e71c25f86f31/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                  silent=True,
#                                                                                                                                  subsample=0.5942105263157895,
#                                                                                                                                  subsample_for_bin=200000,
#                                                                                                                                  subsample_freq=0,
#                                                                                                                                  verbose=-10))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.3333333333333333,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.26666666666666666,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.13333333333333333]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_6531978a_3160_11eb_a86b_000d3aed85c8row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_6531978a_3160_11eb_a86b_000d3aed85c8row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_6531978a_3160_11eb_a86b_000d3aed85c8row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_6531978a_3160_11eb_a86b_000d3aed85c8row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_6531978a_3160_11eb_a86b_000d3aed85c8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6531978a_3160_11eb_a86b_000d3aed85c8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6531978a_3160_11eb_a86b_000d3aed85c8row0_col0" class="data row0 col0" >29054</td>
#                         <td id="T_6531978a_3160_11eb_a86b_000d3aed85c8row0_col1" class="data row0 col1" >204</td>
#             </tr>
#             <tr>
#                         <th id="T_6531978a_3160_11eb_a86b_000d3aed85c8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6531978a_3160_11eb_a86b_000d3aed85c8row1_col0" class="data row1 col0" >1321</td>
#                         <td id="T_6531978a_3160_11eb_a86b_000d3aed85c8row1_col1" class="data row1 col1" >2371</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
